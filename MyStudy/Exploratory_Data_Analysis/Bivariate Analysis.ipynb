# %% [markdown]
# ### Bivariate Analysis
#
# What is the correlation in Gold and Silver prices (round off the answer to two decimal places)? Also, enter a fraction, not a percentage (e.g. 0.34, not 34.00%).

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('EDA_Gold_Silver_prices.csv')
df.head()
# Out:
#     Month  SilverPrice  GoldPrice
# 0  Mar-97       186.48   12619.24
# 1  Apr-97       170.65   12338.59
# 2  May-97       170.44   12314.94
# 3  Jun-97       169.96   12202.78
# 4  Jul-97       155.80   11582.07

# %%
df.corr(method ='pearson')
# Out:
#              SilverPrice  GoldPrice
# SilverPrice     1.000000   0.954256
# GoldPrice       0.954256   1.000000

# %%
df2 = df[df['Month'].str.contains('08')]
df2
# Out:
#       Month  SilverPrice  GoldPrice
# 130  Jan-08       632.29   35025.78
# 131  Feb-08       701.87   36642.46
# 132  Mar-08       775.49   39082.77
# 133  Apr-08       700.96   36416.00
# 134  May-08       718.20   37435.38
# 135  Jun-08       729.63   38087.88
# 136  Jul-08       773.80   40256.56
# 137  Aug-08       625.97   36026.85
# 138  Sep-08       555.58   37815.02
# 139  Oct-08       507.20   39235.79
# 140  Nov-08       483.55   37284.82
# 141  Dec-08       501.82   39696.27

# %%
df2.corr(method ='pearson')
# Out:
#              SilverPrice  GoldPrice
# SilverPrice     1.000000   0.009584
# GoldPrice       0.009584   1.000000

# %%
df2 = df[df['Month'].str.contains('03')]
print(df2.head())
df2.corr(method ='pearson')
# Out:
#      Month  SilverPrice  GoldPrice
# 70  Jan-03       232.76   17104.25
# 71  Feb-03       223.45   17135.72
# 72  Mar-03       216.64   16224.16
# 73  Apr-03       214.92   15548.35
# 74  May-03       223.78   16746.68
#              SilverPrice  GoldPrice
# SilverPrice     1.000000   0.863672
# GoldPrice       0.863672   1.000000

# %%
df = pd.read_csv('currencies.csv')
df.head()
# Out:
#         Currency  Chinese Yuan     Euro  Japanese Yen  U.K. Pound Sterling  \
# 0  July 01, 2016       9.29446  1.25367       143.645              1.05054
# 1  July 05, 2016       9.31515  1.25322       142.715              1.06143
# 2  July 06, 2016       9.31697  1.25834       140.540              1.07300
# 3  July 07, 2016       9.31315  1.25737       140.640              1.06911
# 4  July 08, 2016       9.31350  1.25797       140.510              1.07261
#
#    U.S. Dollar  Algerian Dinar  Australian Dollar  Bahrain Dinar  \
# 0      1.39596             NaN            1.87126       0.524882
# 1      1.39684         154.063            1.85825       0.525213
# 2      1.39286         154.094            1.87313       0.523717
# 3      1.39316         153.957            1.85236       0.523829
# 4      1.39257         154.062            1.85974       0.523607
#
#    Botswana Pula       ...        South African Rand  Sri Lanka Rupee  \
# ...

# %%
df2 = df.corr(method ='pearson').round(2)

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(18, 16), dpi= 80)
plt.matshow(df.corr())
plt
# Out:
# <module 'matplotlib.pyplot' from '/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
df2['Euro']
# Out:
# Chinese Yuan                  0.15
# Euro                          1.00
# Japanese Yen                 -0.65
# U.K. Pound Sterling           0.53
# U.S. Dollar                  -0.21
# Algerian Dinar                0.26
# Australian Dollar             0.33
# Bahrain Dinar                -0.21
# Botswana Pula                 0.47
# Brazilian Real                0.38
# Brunei Dollar                 0.10
# Canadian Dollar               0.64
# Chilean Peso                  0.24
# Czech Koruna                  0.95
# Danish Krone                  1.00
# Hungarian Forint              0.50
# Icelandic Krona               0.41
# Indian Rupee                  0.24
# Israeli New Sheqel            0.64
# Kazakhstani Tenge            -0.52
# Kuwaiti Dinar                -0.03
# Libyan Dinar                   NaN
# Malaysian Ringgit             0.46
# Mauritian Rupee              -0.18
# Mexican Peso                  0.41
# Nepalese Rupee                0.25
# New Zealand Dollar            0.17
# ...

# %%
df = pd.read_csv('nas.csv')
df
# Out:
#             STUID        State  District Gender       Age  Category  \
# 0     26011001001  Maharashtra         1   Girl  13 years       3.0
# 1     26011001002  Maharashtra         1   Girl  15 years       3.0
# 2     26011001003  Maharashtra         1   Girl  14 years       3.0
# 3     26011001004  Maharashtra         1    Boy  13 years       3.0
# 4     26011001005  Maharashtra         1   Girl  14 years       3.0
# 5     26011001006  Maharashtra         1   Girl  13 years       3.0
# 6     26011001007  Maharashtra         1   Girl  14 years       1.0
# 7     26011001013  Maharashtra         1   Girl       NaN       1.0
# 8     26011001014  Maharashtra         1   Girl       NaN       2.0
# 9     26011001015  Maharashtra         1   Girl  13 years       4.0
# 10    26011001017  Maharashtra         1   Girl  15 years       3.0
# 11    26011001018  Maharashtra         1   Girl  13 years       3.0
# 12    26011001019  Maharashtra         1    Boy  15 years       3.0
# ...

# %% [markdown]
# You want to understand the distribution of two variables — mother’s education and the number of siblings. Complete the following statement:
#
# Most children whose mothers are illiterate have:

# %%
df[['Mother.edu','Siblings']][df['Mother.edu']=='Illiterate'].describe()
# Out:
#         Mother.edu    Siblings
# count         2545        2545
# unique           1           5
# top     Illiterate  2 siblings
# freq          2545         923

# %% [markdown]
# You also want to understand how the average science marks vary with the father’s education level and age. Neglect the age group of 11 years since there are very few children in that segment. Mark the correct statement:

# %%
df3 = df[['Father.edu','Age','Science..']]
df3 = df3[pd.notnull(df3['Science..'])]
df3 = df3[pd.notnull(df3['Age'])]
print(df3.head())
df3[df3[]]
# Out:
#       Father.edu       Age  Science..
# 4        Primary  14 years      27.27
# 5        Primary  13 years      27.27
# 14  Sr secondary  15 years      30.91
# 15           NaN  15 years      25.45
# 24     Secondary  12 years      27.27
