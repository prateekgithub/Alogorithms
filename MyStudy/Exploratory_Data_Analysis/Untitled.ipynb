# %% [markdown]
# # Graded Questions
#
# Extract all the relevant metrics (such as the date, day, month, year, hour, and minutes) of each person’s submission and attempt the following questions.
#
# 1. What percentage of students submitted their solutions in .zip format?

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('grades.csv')

num_row,num_col = df.shape

# %%
num_zip = df[df['submission'].str.contains('.zip')].count()
(num_zip/num_row)*100
# Out:
# submission     95.454545
# submit_time    95.454545
# dtype: float64

# %%
df['Order_Date'] = pd.to_datetime(df['submit_time'])

# %%
df['day'] = df['Order_Date'].dt.day
df['month'] = df['Order_Date'].dt.month
df['year'] = df['Order_Date'].dt.year
df['date'] = df['Order_Date'].dt.date
df['hour'] = df['Order_Date'].dt.hour
from datetime import datetime
date_time_str = '2017-01-03 23:59:59'
date_time_obj = datetime.strptime(date_time_str,'%Y-%m-%d %H:%M:%S')
timestamp = datetime.timestamp(date_time_obj)
timestamp
df
# Out:
#                                             submission        submit_time  \
# 0    https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44...  01/03/17-20:28:52
# 1    https://ckd.upgrad.com/UpGrad/185242ff-7508-4c...  01/03/17-20:18:21
# 2    https://ckd.upgrad.com/UpGrad/a353d129-c100-43...  01/03/17-22:37:08
# 3    https://ckd.upgrad.com/UpGrad/002fc912-faa1-49...  01/02/17-21:43:19
# 4    https://ckd.upgrad.com/UpGrad/25cbc4a4-6d49-4f...  01/03/17-15:27:49
# 5    https://ckd.upgrad.com/UpGrad/0ab308ab-2b3a-4c...  01/04/17-02:43:46
# 6    https://ckd.upgrad.com/UpGrad/ba2c249c-dac8-46...  01/03/17-23:41:25
# 7    https://ckd.upgrad.com/UpGrad/d8969806-6760-44...  01/09/17-23:49:09
# 8    https://ckd.upgrad.com/UpGrad/5ff1d0ab-816b-48...  12/30/16-14:14:17
# 9    https://ckd.upgrad.com/UpGrad/0d507851-d102-47...  01/03/17-21:18:04
# 10   https://ckd.upgrad.com/UpGrad/9a756d83-7a83-49...  01/03/17-23:55:41
# 11   https://ckd.upgrad.com/UpGrad/873211b9-5a3q-45...  01/09/17-23:41:23
# ...

# %%
def to_timestamp(row):
    return datetime.timestamp(row['Order_Date'])
df['Timestamp'] = df.apply(to_timestamp,axis=1)
df[df['Timestamp'] > timestamp].count()
date_time_str = '2017-01-04'
#df[df['date'] == datetime.strptime(date_time_str,'%Y-%m-%d')]
#df[df['Order_Date'].str.contains(date_time_str)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-807d959d1e25> in <module>
#       5 date_time_str = '2017-01-04'
#       6 #df[df['date'] == datetime.strptime(date_time_str,'%Y-%m-%d')]
# ----> 7 df[df['Order_Date'].str.contains(date_time_str)]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370         if (name in self._internal_names_set or name in self._metadata or
#    4371                 name in self._accessors):
# -> 4372             return object.__getattribute__(self, name)
#    4373         else:
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     131             # we're accessing the attribute of the class, i.e., Dataset.geo
#     132             return self._accessor
# ...
