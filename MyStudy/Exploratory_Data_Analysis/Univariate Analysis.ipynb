# %%
import pandas as pd
import numpy as np

df = pd.read_csv('popularity_2.csv',sep='\s*,\s*',engine='python')
df.shape
# Out:
# (39644, 61)

# %%
df.describe()
# Out:
#           timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# count  39644.000000    39644.000000      39644.000000     39644.000000
# mean     354.530471       10.398749        546.514731         0.548216
# std      214.163767        2.114037        471.107508         3.520708
# min        8.000000        2.000000          0.000000         0.000000
# 25%      164.000000        9.000000        246.000000         0.470870
# 50%      339.000000       10.000000        409.000000         0.539226
# 75%      542.000000       12.000000        716.000000         0.608696
# max      731.000000       23.000000       8474.000000       701.000000
#
#        n_non_stop_words  n_non_stop_unique_tokens     num_hrefs  \
# count      39644.000000              39644.000000  39644.000000
# mean           0.996469                  0.689175     10.883690
# std            5.231231                  3.264816     11.332017
# min            0.000000                  0.000000      0.000000
# ...

# %%
df.describe().loc['mean','shares']
# Out:
# 3395.3801836343455

# %%
# percentile list 
perc =[.30, .40, .50, .60, .70, .80] 
df.describe(percentiles=perc)
# Out:
#           timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# count  39644.000000    39644.000000      39644.000000     39644.000000
# mean     354.530471       10.398749        546.514731         0.548216
# std      214.163767        2.114037        471.107508         3.520708
# min        8.000000        2.000000          0.000000         0.000000
# 30%      197.000000        9.000000        276.000000         0.485408
# 40%      265.000000       10.000000        335.000000         0.513218
# 50%      339.000000       10.000000        409.000000         0.539226
# 60%      426.000000       11.000000        507.000000         0.565574
# 70%      504.000000       11.000000        633.000000         0.593107
# 80%      582.000000       12.000000        810.000000         0.626335
# max      731.000000       23.000000       8474.000000       701.000000
#
#        n_non_stop_words  n_non_stop_unique_tokens     num_hrefs  \
# ...

# %%
perc =[.95] 
df.describe(percentiles=perc)[['shares']]
# Out:
#               shares
# count   39644.000000
# mean     3395.380184
# std     11626.950749
# min         1.000000
# 50%      1400.000000
# 95%     10800.000000
# max    843300.000000

# %%
df2 = df[df.shares <= 10800]

# %%
count2 = df2.describe().loc['count','shares']
count2
# Out:
# 37663.0

# %%
count1 = df.describe().loc['count','shares']
count1
# Out:
# 39644.0

# %%
(count1-count2)/count1
# Out:
# 0.04996973060236101
